# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("./raw/Amazon Sale Report.csv")
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %%
print(df.dtypes)
print("\n")
print(df.shape)
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# B2B                      bool
# fulfilled-by           object
# New                   float64
# PendingS              float64
# dtype: object
#
#
# (128976, 21)

# %%
df.duplicated().sum()
# Out:
# 168

# %% [markdown]
# ## Drop duplicated values

# %%
df[df.duplicated()]
# Out:
#       index             Order ID      Date                        Status  \
# 201       6  408-5748499-6859555  04-30-22                       Shipped
# 202       7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 203       8  407-5443024-5233168  04-30-22                     Cancelled
# 204       9  402-4393761-0311520  04-30-22                       Shipped
# 205      10  407-5633625-6970741  04-30-22                       Shipped
# ...     ...                  ...       ...                           ...
# 6640   6278  171-5170733-7855514  04-26-22  Shipped - Delivered to Buyer
# 6641   6279  403-8137343-5206760  04-26-22  Shipped - Delivered to Buyer
# 6642   6280  408-1575454-3263526  04-26-22  Shipped - Returned to Seller
# 6643   6281  171-2918708-7197155  04-26-22  Shipped - Delivered to Buyer
# 6644   6282  406-7244956-4740355  04-26-22                       Shipped
#
#      Fulfilment Sales Channel ship-service-level  Category Size  \
# ...

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Handle null values

# %%
df.isnull().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7789
# Amount                  7789
# ship-city                 33
# ship-state                33
# ship-postal-code          33
# ship-country              33
# B2B                        0
# fulfilled-by           89595
# New                   128808
# PendingS              128808
# dtype: int64

# %% [markdown]
# - index, Order ID don't have meaning in visualize.
# - New and PendingS have null values same as the values of the data so i will drop it.

# %%
df.drop(['index', 'Order ID', 'New', 'PendingS'], axis=1, inplace=True)
df.head()
# Out:
#        Date                        Status Fulfilment Sales Channel  \
# 0  04-30-22                     Cancelled   Merchant     Amazon.in
# 1  04-30-22  Shipped - Delivered to Buyer   Merchant     Amazon.in
# 2  04-30-22                       Shipped     Amazon     Amazon.in
# 3  04-30-22                     Cancelled   Merchant     Amazon.in
# 4  04-30-22                       Shipped     Amazon     Amazon.in
#
#   ship-service-level  Category Size Courier Status  Qty currency  Amount  \
# 0           Standard   T-shirt    S     On the Way    0      INR  647.62
# 1           Standard     Shirt  3XL        Shipped    1      INR  406.00
# 2          Expedited     Shirt   XL        Shipped    1      INR  329.00
# 3           Standard   Blazzer    L     On the Way    0      INR  753.33
# 4          Expedited  Trousers  3XL        Shipped    1      INR  574.00
#
#      ship-city   ship-state  ship-postal-code ship-country    B2B fulfilled-by
# ...

# %%
df.isnull().sum()
# Out:
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7789
# Amount                 7789
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# B2B                       0
# fulfilled-by          89595
# dtype: int64

# %%
df[df['currency'].isnull()]
# Out:
#             Date     Status Fulfilment Sales Channel ship-service-level  \
# 8       04-30-22  Cancelled     Amazon     Amazon.in          Expedited
# 29      04-30-22  Cancelled   Merchant     Amazon.in           Standard
# 65      04-30-22  Cancelled     Amazon     Amazon.in          Expedited
# 84      04-30-22  Cancelled     Amazon     Amazon.in          Expedited
# 95      04-30-22  Cancelled     Amazon     Amazon.in          Expedited
# ...          ...        ...        ...           ...                ...
# 128904  05-31-22  Cancelled     Amazon     Amazon.in          Expedited
# 128908  05-31-22  Cancelled     Amazon     Amazon.in          Expedited
# 128909  05-31-22  Cancelled     Amazon     Amazon.in          Expedited
# 128959  05-31-22  Cancelled     Amazon     Amazon.in          Expedited
# 128968  05-31-22  Cancelled     Amazon     Amazon.in          Expedited
#
#        Category Size Courier Status  Qty currency  Amount      ship-city  \
# ...

# %%
currency_null = df[df['currency'].isnull()]
amount_null = df[df['Amount'].isnull()]

currency_null.equals(amount_null)
# Out:
# True

# %%
df['currency'].value_counts().to_frame()
# Out:
#            count
# currency
# INR       121019

# %% [markdown]
# - Can see that when the currency is null then the amount is also null.
# - All of the values in currency in currency is INR (Indian Rupee) so it don't need to visualize --> drop.

# %%
df.drop('currency', axis=1, inplace=True)
df
# Out:
#             Date                        Status Fulfilment Sales Channel  \
# 0       04-30-22                     Cancelled   Merchant     Amazon.in
# 1       04-30-22  Shipped - Delivered to Buyer   Merchant     Amazon.in
# 2       04-30-22                       Shipped     Amazon     Amazon.in
# 3       04-30-22                     Cancelled   Merchant     Amazon.in
# 4       04-30-22                       Shipped     Amazon     Amazon.in
# ...          ...                           ...        ...           ...
# 128971  05-31-22                       Shipped     Amazon     Amazon.in
# 128972  05-31-22                       Shipped     Amazon     Amazon.in
# 128973  05-31-22                       Shipped     Amazon     Amazon.in
# 128974  05-31-22                       Shipped     Amazon     Amazon.in
# 128975  05-31-22                       Shipped     Amazon     Amazon.in
#
#        ship-service-level  Category Size Courier Status  Qty   Amount  \
# ...

# %% [markdown]
# ## Save cleaned dataframe

# %%
df.to_csv("./cleaned/cleaned_data.csv", index=False)
